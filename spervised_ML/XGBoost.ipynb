# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamedshouaib/iti/blob/main/spervised_ML/XGBoost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/s7s/machine_learning_1.git
# %cd  machine_learning_1/ensemble_methods
# Out:
# Cloning into 'machine_learning_1'...
# remote: Enumerating objects: 378, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (125/125), done.
# remote: Total 378 (delta 74), reused 3 (delta 1), pack-reused 252 (from 1)
# Receiving objects: 100% (378/378), 42.71 MiB | 9.03 MiB/s, done.
# Resolving deltas: 100% (197/197), done.
# /content/machine_learning_1/ensemble_methods

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
import utils
import sklearn
from sklearn import tree
import matplotlib.pyplot as plt

# %%
features = np.array([[10],[20],[30],[40],[50],[60],[70],[80]])
labels = np.array([7,5,7,1,2,1,5,4])

# %%
plt.scatter(features, labels)
plt.xlabel("Age")
plt.ylabel("Days per week")
plt.show()

# %% [markdown]
# # XGBoost

# %%
import xgboost
from xgboost import XGBRegressor
# use xgboost with [ n_estimators=3, max_depth=2, reg_lambda=0, min_split_loss=1, learning_rate=0.7]
xgboost_regressor = XGBRegressor(
    n_estimators=3,
    max_depth=2,
    reg_lambda=0,
    gamma=1,
    learning_rate=0.7,
    random_state=42
)
xgboost_regressor.fit(features,labels)
xgboost_regressor.score(features, labels)
# Out:
# 0.9013694524765015

# %%
utils.plot_regressor(xgboost_regressor, features, labels)

# %%
xgboost_regressor.predict(features)
# Out:
# array([6.1233335, 6.1233335, 6.1233335, 1.5733333, 1.5733333, 1.5733333,
#        4.455    , 4.455    ], dtype=float32)
